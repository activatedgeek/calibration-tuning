# %%
import pandas as pd

# %%
results = pd.read_csv("results/oe_sampling.csv")

# %%
results.columns
# Out:
# Index(['Unnamed: 0', 'N', 'substring_acc', 'substring_ece_counting',
#        'substring_ece_likelihood', 'substring_ece_likelihood_normalized',
#        'fuzzy_gpt-3.5-turbo-1106_acc', 'fuzzy_gpt-3.5-turbo-1106_ece_counting',
#        'fuzzy_gpt-3.5-turbo-1106_ece_likelihood',
#        'fuzzy_gpt-3.5-turbo-1106_ece_likelihood_normalized', 'split', 'seed',
#        'model_name', 'model_dir', 'peft_dir', 'query_peft_dir', 'eval_kshot',
#        'prompt_style', 'mode', 'output_row_path', 'dataset', 'ts'],
#       dtype='object')

# %%
results[["dataset", "split", "fuzzy_gpt-3.5-turbo-1106_acc", "fuzzy_gpt-3.5-turbo-1106_ece_likelihood_normalized", "fuzzy_gpt-3.5-turbo-1106_ece_counting"]]
# Out:
#                      dataset       split  fuzzy_gpt-3.5-turbo-1106_acc  \
# 0      mmlu:medical_genetics  validation                      0.272727
# 1      mmlu:medical_genetics        test                      0.320000
# 2    mmlu:clinical_knowledge  validation                      0.103448
# 3    mmlu:clinical_knowledge        test                      0.222642
# 4               mmlu:anatomy  validation                      0.357143
# 5               mmlu:anatomy        test                      0.296296
# 6     mmlu:logical_fallacies  validation                      0.333333
# 7     mmlu:logical_fallacies        test                      0.251534
# 8           mmlu:human_aging  validation                      0.173913
# 9           mmlu:human_aging        test                      0.251121
# 10         mmlu:formal_logic  validation                      0.428571
# 11         mmlu:formal_logic        test                      0.365079
# ...
